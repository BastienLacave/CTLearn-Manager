# %%
from ctlearn_manager import load_model_from_index
from ctlearn_manager.utils import ClusterConfiguration

# %% [markdown]
# # 🧠 Load `CTLearnModelManager`
# `CTLearnModelManager` is an object that allows you to setup and train a CTLearn model

# %%
MODEL_INDEX_FILE = "/users/blacave/PhD/LST/CTLearnManager/ctlearn_models_index.h5"
model = load_model_from_index("LST1_cameradirection_CRABdec_0", MODEL_INDEX_FILE)
model.plot_loss()
# model.info()
# Out:
# 🔧 Using cluster cscs with account cta03 and python environment ctlearn, partition gpu and time limit 15:00

# %% [markdown]
# # 🚀 Launch training

# %%
model.launch_training(n_epochs=15, transfer_learning_model_cpk, config=blabla)
# Out:
# 📊 Model trained for 0 epochs
# 🚀 Launching training for 15 epochs
# 🆕 Model does not exist: will create LST1_cameradirection_CRABdec_0_v0
# --pattern-signal "gamma_theta_37.661_az_270.641_runs1-421.dl1.h5" --pattern-signal "gamma_theta_30.390_az_266.360_runs1-421.dl1.h5"
# --pattern-signal "gamma_theta_37.661_az_270.641_runs1-421.dl1.h5" --pattern-signal "gamma_theta_30.390_az_266.360_runs1-421.dl1.h5"
# Configuration saved to /capstor/scratch/cscs/blacave/CTLearn_Models//LST1_cameradirection_CRABdec_0_v0//train_config.json
# 💾 Testing script saved in /capstor/scratch/cscs/blacave/CTLearn_Models//LST1_cameradirection_CRABdec_0_v0//LST1_cameradirection_CRABdec_0.sh
# Submitted batch job 623572
